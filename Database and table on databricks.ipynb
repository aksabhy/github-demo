-- %%
%sql
use catalog hive_metastore;

drop table if exists managed_default;

create table managed_default
(width int,length int,height int);

insert into managed_default values (1 int, 2 int, 3 int);

-- %%
%sql
describe extended managed_default;

-- %%
%sql
create table extternal_default
(width int,length int,height int)
location 'dbfs:/mnt/demo/external_default';

insert into extternal_default values (1 int, 2 int, 3 int)

-- %%
%sql
describe extended extternal_default

-- %%
%sql
drop table managed_default

-- %%
%fs ls dbfs:/user/hive/warehouse/managed_default

-- %%
%sql
drop table extternal_default

-- %%
%fs ls dbfs:/mnt/demo/external_default

-- %%
%sql
create schema new_default;

-- %%
describe database extended new_default;
